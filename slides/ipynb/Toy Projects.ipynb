# %%
from traitlets.config.manager import BaseJSONConfigManager
path = "/Users/mert/.jupyter/nbconfig"
cm = BaseJSONConfigManager(config_dir=path)
cm.update('livereveal', {
              'theme': 'solarized',
              'transition': 'slide', # none/fade/slide/convex/concave/zoom
              'start_slideshow_at': 'selected',
              'scroll': False,
              'history': False ,
              'progress': True,
})
# Out:
# {'height': 768,
#  'history': False,
#  'progress': True,
#  'scroll': False,
#  'start_slideshow_at': 'selected',
#  'theme': 'solarized',
#  'transition': 'slide',
#  'width': 1024}

# %% [markdown]
# # Toy Projects

# %% [markdown]
# ### Toy Projects
# * **Cloud and Faces**: Daten über API holen, säubern, Face Detection, Google Cloud Vision API
# * **Trumps Tweets**: Monkeylearn API, Pandas, Supervised Learning
#
# ### Beispiele
# * Pytanic (Predict Survival on the Titanic)
# * Interactive Intro to Dimensionality Reduction
# * Strength of Visualization

# %% [markdown]
# ### Advanced
# * [Scikit Learn Tutorial](http://scikit-learn.org/stable/tutorial/basic/tutorial.html)
# * [John Wittenauer's Machine Learning Basics](http://www.johnwittenauer.net/machine-learning-exercises-in-python-part-1/)
