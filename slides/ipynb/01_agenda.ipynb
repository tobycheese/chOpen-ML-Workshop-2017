# %%
from traitlets.config.manager import BaseJSONConfigManager
path = "/Users/mert/.jupyter/nbconfig"
cm = BaseJSONConfigManager(config_dir=path)
cm.update('livereveal', {
              'theme': 'solarized',
              'transition': 'slide', # none/fade/slide/convex/concave/zoom
              'start_slideshow_at': 'selected',
              'scroll': False,
              'history': False ,
              'progress': True,
})
# Out:
# {'height': 768,
#  'history': False,
#  'progress': True,
#  'scroll': False,
#  'start_slideshow_at': 'selected',
#  'theme': 'solarized',
#  'transition': 'slide',
#  'width': 1024}

# %% [markdown]
# # Machine Learning für Software Entwickler

# %% [markdown]
# Workshoptage 11. und 12. September 2017

# %% [markdown]
# ## Ablauf

# %% [markdown]
# ### Vormittag
# 1. Vorstellung
# 1. Machine Learning im Überblick
# 1. *Kaffeepause (ca. 10:30)*
# 1. Machine Learning Ablauf an einem Beispiel
# 1. Abgrenzung und Begriffe
# 1. Voraussetzungen für erfolgreiches Machine Learning
# 1. Machine Learning und die Softwareentwicklung

# %% [markdown]
# ### Mittagspause
# 12:45 - 14:00

# %% [markdown]
# ### Nachmittag
# 1. Recap
# 1. Toy Projects
# 1. *Kaffeepause (zwischen 15:30 und 16:00)*
# 1. Trends im Machine Learning
# 1. Feedbackrunde
