# %%
from traitlets.config.manager import BaseJSONConfigManager
path = "/Users/mert/.jupyter/nbconfig"
cm = BaseJSONConfigManager(config_dir=path)
cm.update('livereveal', {
              'theme': 'solarized',
              'transition': 'slide', # none/fade/slide/convex/concave/zoom
              'start_slideshow_at': 'selected',
              'scroll': False,
              'history': False ,
              'progress': True,
})
# Out:
# {'height': 768,
#  'history': False,
#  'progress': True,
#  'scroll': False,
#  'start_slideshow_at': 'selected',
#  'theme': 'solarized',
#  'transition': 'slide',
#  'width': 1024}

# %% [markdown]
# # Recap

# %% [markdown]
# * **Gruppe 1**: Die drei Bereiche von Machine Learning erläutern, je ein Beispiel bringen
# * **Gruppe 2**: Die Prozesseschritte von Supervised Learning auflisten und mit Stichworten erläutern
# * **Gruppe 3**: Voraussetzungen für Supervised Learning nennen und mit Stichworten beschreiben
# * **Gruppe 4**: Data Hierarchy of Needs aufzeichnen und mit Stichworten den Beitrag von Engineers beschreiben
